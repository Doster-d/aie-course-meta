# %% [markdown]
# # Работа с табличными данными
# Большое количество данных, которые используются в машинном обучении, представлены в виде таблиц, где в столбцах представлены различные признаки и целевые переменные.
# Для работы с такими данными в Python есть замечательная библиотека [`pandas`](https://pandas.pydata.org/docs/user_guide/index.html) тесно связанная с уже известной нам `numpy`. К пандам отношения не имеет, название пошло от "панельные данные".

# %% [markdown]
# # Pandas
# ## Создание и индексация
# В `pandas` два основных вида объектов (типов) Series и Dataframe, они похожи между собой, но Dataframe это фактически таблица, в которой есть строки, столбцы, а Series это один столбец со строками.
# Столбцы и\или строки могут иметь названия, которые выступают их индексами и к определенному столбцу (или строке) можно обращаться именно по названию.
#
# Создадим Series (давайте назовем это последовательностью), в которой будут записаны некоторые данные имеющие названия (индексы). И данные (data) и индексы (index) могут иметь различный тип: числа, строки, объекты.
#
# Но будьте аккуратны, индексы надо делать так, чтобы было понятно. Ниже увидим примеры разрешенных, но совершенно не понятных индексов.

# %%
import pandas as pd # подключим библиотеку
import numpy as np

# %%
s = pd.Series(data=[10, "11", ['a',12], 'ppp', 14, 42], # данные
              index=[2.1, '2', 'два', 2, 2.1, -2]) # их индексы
s # здесь 5 ячеек
# Out:
# 2.1         10
# 2           11
# два    [a, 12]
# 2          ppp
# 2.1         14
# -2          42
# dtype: object

# %% [markdown]
# в этой последовательности 6 ячеек (data) и к ним можно обратиться по индексам (index), важно понять, что здесь индексы именно названия, а не номера строк.

# %%
print(s[2]) # здесь вернется подпоследовательность элементов у которых индекс называется 2 (первая и четвертая ячейки)
print('\n')
print(s['2']) # это ячейка с названием '2', это совершенно другой индекс, отличается от названия 2 (вторая ячейка)
print('\n')
print(s['два']) # это ячейка с названием 'два', третья ячейка, в которой записан массив
print('\n')
print(s[-2]) # это ячейка с названием -2, пятая ячейка
# Out:
# ppp
#
#
# 11
#
#
# ['a', 12]
#
#
# 42

# %%
s['hello'] # такого нет
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# index.pyx in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'hello'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1633865348.py in <cell line: 0>()
# ----> 1 s['hello'] # такого нет
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1235
#    1236         # Similar to Index.get_value, but we do not fall back to positional
# -> 1237         loc = self.index.get_loc(label)
#    1238
#    1239         if is_integer(loc):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'hello'

# %%
zz=s[2.1] # а такой есть, но это не номер, а название индекса
zz
# Out:
# 2.1    10
# 2.1    14
# dtype: object

# %% [markdown]
# Как и в numpy можно делать срезы, в этом случае указываются номера, а не названия элементов.

# %%
s
# Out:
# 2.1         10
# 2           11
# два    [a, 12]
# 2          ppp
# 2.1         14
# -2          42
# dtype: object

# %%
s[1:4] # срез, вторая и третья ячейки, здесь это номера, а не названия.
# Out:
# 2           11
# два    [a, 12]
# 2          ppp
# dtype: object

# %%
s[1:2]
# Out:
# 2    11
# dtype: object

# %%
s[1] # это ошибка, нет элемента с названием 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# index.pyx in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-72102545.py in <cell line: 0>()
# ----> 1 s[1] # это ошибка, нет элемента с названием 1
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1235
#    1236         # Similar to Index.get_value, but we do not fall back to positional
# -> 1237         loc = self.index.get_loc(label)
#    1238
#    1239         if is_integer(loc):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 1

# %% [markdown]
# Но срезы могут быть строковыми (удивительно), тогда это именно названия. Pandas сопоставит символьные индексы числовым, найдет их в последовательности, и вернет все, что между ними, включая границы.

# %%
v = pd.Series(data=[10, "11", ['a',12], 'ppp', 14], # данные
              index=['a', 'f', 'c', 'd', 'e']) # их индексы
v['a':'d']
# v['a':'g'] # так работать не будет, потому что индекса 'g' нет.
# Out:
# a         10
# f         11
# c    [a, 12]
# d        ppp
# dtype: object

# %% [markdown]
# Создайте свои последовательности, обратитесь к элементам. Проверьте, что будет если при создании последовательности не указать index?  А если при строковом индексе в последовательности индексы будут повторяться?
#
# Аналогично можно создать таблицу Dataframe, в которой несколько столбцов.

# %%
df = pd.DataFrame([[10, 'aaa'], [s, 21], [30, 31]])
df
# Out:
#                                                    0    1
# 0                                                 10  aaa
# 1  2.1         10
# 2           11
# два    [a, 12]
# 2...   21
# 2                                                 30   31

# %% [markdown]
# здесь два столбца, три строки, названия их сделаны по умолчанию, в одну ячейку мы записали последовательность s.
# Столбцы (columns) и строки (index) можно назвать.

# %%
df = pd.DataFrame([[10, 'aaa'], [s, 21], [30, 31]],
                  columns=['невторой',2],
                  index=[1,'1','один'])
df
# Out:
#                                                невторой    2
# 1                                                    10  aaa
# 1     2.1         10
# 2           11
# два    [a, 12]
# 2...   21
# один                                                 30   31

# %%
df[1:'один']
# Out:
#                                                невторой    2
# 1                                                    10  aaa
# 1     2.1         10
# 2           11
# два    [a, 12]
# 2...   21
# один                                                 30   31

# %% [markdown]
# При индексации по названию сначала указываем название столбца - вернется весь столбец в виде последовательности - потом для нее указываем название строки.

# %%
s0=df['невторой']
s0
# Out:
# 1                                                      10
# 1       2.1         10
# 2           11
# два    [a, 12]
# 2...
# один                                                   30
# Name: невторой, dtype: object

# %%
s1=df['невторой']['один']
s1
# Out:
# 30

# %% [markdown]
# Названия столбцов содержатся в атрибуте columns и их можно изменять.
#
# В некоторых случаях к столбцу можно обратиться как к атрибуту через знак "." Но это работает не всегда.
# Попробуйте назвать столбец "столбец 1" или 'index' или "1" и посмотрите, что получится.

# %%
df.columns=['невторой','second']
#df.columns=['index','second']
df
# Out:
#                                                невторой second
# 1                                                    10    aaa
# 1     2.1         10
# 2           11
# два    [a, 12]
# 2...     21
# один                                                 30     31

# %%
df.невторой # работает, название столбца как атрибут
# Out:
# 1                                                      10
# 1       2.1         10
# 2           11
# два    [a, 12]
# 2...
# один                                                   30
# Name: невторой, dtype: object

# %%
df.columns=['столбец 1',2] # изменяем названия столбцов
df['столбец 1']
# Out:
# 1                                                      10
# 1       2.1         10
# 2           11
# два    [a, 12]
# 2...
# один                                                   30
# Name: столбец 1, dtype: object

# %%
#  а вот с такими названиями работать не будет
#df.столбец 1
df.'столбец 1'
# Out:
#   File "/tmp/ipython-input-1129031264.py", line 3
#     df.'столбец 1'
#        ^
# SyntaxError: invalid syntax

# %%
df.columns=['index','second']
df['index']
# Out:
# 1                                                      10
# 1       2.1         10
# 2           11
# два    [a, 12]
# 2...
# один                                                   30
# Name: index, dtype: object

# %%
# так ошибку не выдает, но выдает что-то не то. Это потому, что index уже определен как атрибут
df.index
# Out:
# Index([1, '1', 'один'], dtype='object')

# %% [markdown]
# Атрибут index возвращает индекс (названия строк)
#
# Атрибут columns возвращает названия столбцов (для таблиц)
#
# Атрибут values возвращает значения ячеек как массив numpy

# %%
print(df.index)
print(df.columns)
print(df.values)
print(type(df.values))
# Out:
# Index([1, '1', 'один'], dtype='object')
# Index(['index', 'second'], dtype='object')
# [[10 'aaa']
#  [2.1         10
#   2           11
#   два    [a, 12]
#   2          ppp
#   2.1         14
#   -2          42
#   dtype: object  21]
#  [30 31]]
# <class 'numpy.ndarray'>

# %% [markdown]
# Срез выполняется по строкам

# %%
df[1:2]
# Out:
#                                                index second
# 1  2.1         10
# 2           11
# два    [a, 12]
# 2...     21

# %% [markdown]
# Если нужно обращаться по номеру (числовому индексу), используем атрибут iloc, как если бы это был массив numpy.

# %%
df
# Out:
#                                                   index second
# 1                                                    10    aaa
# 1     2.1         10
# 2           11
# два    [a, 12]
# 2...     21
# один                                                 30     31

# %%
df
# Out:
#                                                   index second
# 1                                                    10    aaa
# 1     2.1         10
# 2           11
# два    [a, 12]
# 2...     21
# один                                                 30     31

# %%
df.iloc[1,0]
# Out:
# 2.1         10
# 2           11
# два    [a, 12]
# 2          ppp
# 2.1         14
# -2          42
# dtype: object

# %%
df.iloc[1,-1]
# Out:
# 21

# %% [markdown]
# Индексация может быть логической, истинные элементы (True) отбираются, ложные (False) отбрасываются.

# %%
np.random.seed(123)
s = pd.Series(np.random.normal(size=10))
print(s)
ind=s>0
print(ind)
r=s[ind]
print(r)
# Out:
# 0   -1.085631
# 1    0.997345
# 2    0.282978
# 3   -1.506295
# 4   -0.578600
# 5    1.651437
# 6   -2.426679
# 7   -0.428913
# 8    1.265936
# 9   -0.866740
# dtype: float64
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# 9    False
# dtype: bool
# 1    0.997345
# 2    0.282978
# 5    1.651437
# 8    1.265936
# dtype: float64

# %%
print(ind)
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# 9    False
# dtype: bool

# %% [markdown]
# Другие способы создания и индексации смотри в документации.

# %% [markdown]
# ## Загрузка из файла

# %% [markdown]
# Если б таблички нужно было создавать вручную, это было бы слишком утомительно, к счастью, pandas обладает богатыми возможностями по загрузке файлов таблиц разного формата, \*.csv, \*.xls и других, как с диска так и из Интернет.
#
# Команда [`read_csv()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) позволяет загрузить файлы csv с заданного файла на диске или адреса в Интернет (первый обязательный аргумент `filepath_or_buffer`). Это текстовые файлы, в которых столбцы таблиц разделяются некоторым символом (запятая, точка с запятой или другие), который можно указать команде (аргумент `sep`), возвращается объект типа Dataframe. У команды большие возможности по загрузке данных, можно ограничить количество загружаемых строк (аргумент `nrows`), можно указать загружаемые столбцы (аргумент `usecols`), указать, что делать со строками с пропущенными значениями и другие.
#
# Давайте загрузим табличку о 500 лучших компаниях мира с адреса https://datahub.io/core/s-and-p-500-companies-financials#resource-constituents-financials  , с разделителями столбцов в виде запятой. В нашем примере по умолчанию названия столбцов будут взяты из первой строки файла, в которой они и указаны. _(Если в силу каких-то причин из Интернета не загружается, то скачайте вручную, исправьте url на file, чтобы загрузить уже скаченную копию таблицы или скачайте с другого адреса.)_

# %%
url = 'https://datahub.io/core/s-and-p-500-companies-financials/r/constituents-financials.csv'
#url = 'https://raw.githubusercontent.com/datasets/s-and-p-500-companies-financials/main/data/constituents-financials.csv'
file='constituents-financials_csv.csv'
data = pd.read_csv(url, sep=',')
data
# Out:
#     Symbol                 Name                                        Sector  \
# 0      MMM                   3M                      Industrial Conglomerates
# 1      AOS          A. O. Smith                             Building Products
# 2      ABT  Abbott Laboratories                         Health Care Equipment
# 3     ABBV               AbbVie                                 Biotechnology
# 4      ACN            Accenture                IT Consulting & Other Services
# ..     ...                  ...                                           ...
# 498    XYL           Xylem Inc.  Industrial Machinery & Supplies & Components
# 499    YUM          Yum! Brands                                   Restaurants
# 500   ZBRA   Zebra Technologies            Electronic Equipment & Instruments
# 501    ZBH        Zimmer Biomet                         Health Care Equipment
# 502    ZTS               Zoetis                               Pharmaceuticals
#
#       Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0    152.20       21.286713          0.0199            7.15    75.652176
# 1     67.30       18.539946          0.0196            3.63    66.760000
# 2    127.93       16.744764          0.0202            7.64    99.710000
# 3    183.90       64.300700          0.0373            2.86   153.580000
# 4    384.95       32.294464          0.0170           11.92   278.690000
# ..      ...             ...             ...             ...          ...
# 498  124.04       35.643677          0.0118            3.48   112.020000
# 499  130.50       24.392525          0.0205            5.35   122.130000
# 500  391.94       53.397820             NaN            7.34   237.060000
# 501  109.48       20.893131          0.0087            5.24   100.670000
# 502  170.90       32.124058          0.0116            5.32   144.800000
#
#      52 Week High    Market Cap        EBITDA  Price/Sales  Price/Book  \
# 0          155.00  8.329418e+10  8.117000e+09     2.552062   17.855467
# 1           92.45  9.758165e+09  8.091000e+08     2.506078    5.091157
# 2          129.85  2.218895e+11  1.082500e+10     5.383446    5.575749
# 3          207.32  3.249770e+11  2.563000e+10     5.851963   53.882210
# 4          387.51  2.407785e+11  1.106591e+10     3.710195    8.508687
# ..            ...           ...           ...          ...         ...
# 498        146.08  3.013490e+10  1.689000e+09     3.577267    2.845411
# 499        143.20  3.641890e+10  2.608000e+09     5.042073         NaN
# 500        427.76  2.021626e+10  8.030000e+08     4.341981    5.905112
# 501        133.90  2.179462e+10  2.557400e+09     2.869412    1.765892
# 502        200.53  7.710410e+10  3.764000e+09     8.424835   14.744198
#
#                                            SEC Filings
# 0    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 2    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4    http://www.sec.gov/cgi-bin/browse-edgar?action...
# ..                                                 ...
# 498  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 499  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 500  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 501  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 502  http://www.sec.gov/cgi-bin/browse-edgar?action...
#
# [503 rows x 14 columns]

# %%
data.shape # сколько строк и столбцов?
# Out:
# (503, 14)

# %%
# выводит первые несколько строк
data.head(n=50)
# Out:
#    Symbol                             Name  \
# 0     MMM                               3M
# 1     AOS                      A. O. Smith
# 2     ABT              Abbott Laboratories
# 3    ABBV                           AbbVie
# 4     ACN                        Accenture
# 5    ADBE                       Adobe Inc.
# 6     AMD           Advanced Micro Devices
# 7     AES                  AES Corporation
# 8     AFL                            Aflac
# 9       A             Agilent Technologies
# 10    APD                     Air Products
# 11   ABNB                           Airbnb
# 12   AKAM              Akamai Technologies
# 13    ALB            Albemarle Corporation
# 14    ARE  Alexandria Real Estate Equities
# 15   ALGN                 Align Technology
# 16   ALLE                         Allegion
# 17    LNT                   Alliant Energy
# 18    ALL                         Allstate
# 19  GOOGL          Alphabet Inc. (Class A)
# 20   GOOG          Alphabet Inc. (Class C)
# 21     MO                           Altria
# 22   AMZN                           Amazon
# 23   AMCR                            Amcor
# 24   AMTM                          Amentum
# 25    AEE                           Ameren
# 26    AEP          American Electric Power
# 27    AXP                 American Express
# 28    AIG     American International Group
# 29    AMT                   American Tower
# 30    AWK             American Water Works
# 31    AMP             Ameriprise Financial
# 32    AME                           Ametek
# 33   AMGN                            Amgen
# 34    APH                         Amphenol
# 35    ADI                   Analog Devices
# 36   ANSS                            Ansys
# 37    AON                              Aon
# 38    APA                  APA Corporation
# 39   AAPL                       Apple Inc.
# 40   AMAT                Applied Materials
# 41   APTV                            Aptiv
# 42   ACGL               Arch Capital Group
# 43    ADM           Archer Daniels Midland
# 44   ANET                  Arista Networks
# 45    AJG        Arthur J. Gallagher & Co.
# 46    AIZ                         Assurant
# 47      T                             AT&T
# 48    ATO                     Atmos Energy
# 49   ADSK                         Autodesk
#
#                                             Sector   Price  Price/Earnings  \
# 0                         Industrial Conglomerates  152.20       21.286713
# 1                                Building Products   67.30       18.539946
# 2                            Health Care Equipment  127.93       16.744764
# 3                                    Biotechnology  183.90       64.300700
# 4                   IT Consulting & Other Services  384.95       32.294464
# 5                             Application Software  437.45       35.421050
# 6                                   Semiconductors  115.95      105.409090
# 7     Independent Power Producers & Energy Traders   11.00        7.638888
# 8                          Life & Health Insurance  107.38       15.955423
# 9                   Life Sciences Tools & Services  151.52       34.126125
# 10                                Industrial Gases  335.26       19.469223
# 11                  Hotels, Resorts & Cruise Lines  131.17       45.387543
# 12              Internet Services & Infrastructure   99.90       29.556213
# 13                             Specialty Chemicals   84.19             NaN
# 14                                    Office REITs   97.35       54.083332
# 15                            Health Care Supplies  219.11       37.390785
# 16                               Building Products  132.73       20.420000
# 17                              Electric Utilities   58.88       22.910507
# 18                   Property & Casualty Insurance  192.33       12.432449
# 19                    Interactive Media & Services  204.02       27.094290
# 20                    Interactive Media & Services  205.60       27.267906
# 21                                         Tobacco   52.23        7.877828
# 22                                Broadline Retail  237.68       50.249470
# 23  Paper & Plastic Packaging Products & Materials    9.72       18.339624
# 24                    Diversified Support Services   20.97             NaN
# 25                                 Multi-Utilities   94.20       22.164705
# 26                              Electric Utilities   98.36       19.830645
# 27                                Consumer Finance  317.45       22.772598
# 28                            Multi-line Insurance   73.66       14.644135
# 29                             Telecom Tower REITs  184.95       44.673912
# 30                                 Water Utilities  124.64       24.681187
# 31                Asset Management & Custody Banks  543.36       21.795425
# 32               Electrical Components & Equipment  184.56       32.097390
# 33                                   Biotechnology  285.42       36.220814
# 34                           Electronic Components   70.78       36.864582
# 35                                  Semiconductors  211.89       64.798164
# 36                            Application Software  350.50       53.923077
# 37                               Insurance Brokers  370.82       31.721130
# 38              Oil & Gas Exploration & Production   21.93        3.115057
# 39      Technology Hardware, Storage & Peripherals  236.00       37.760000
# 40             Semiconductor Materials & Equipment  180.35       21.093567
# 41                    Automotive Parts & Equipment   62.42        7.005611
# 42                   Property & Casualty Insurance   93.07        6.348567
# 43                Agricultural Products & Services   51.23       14.390450
# 44                        Communications Equipment  115.23       55.399040
# 45                               Insurance Brokers  301.82       46.505394
# 46                            Multi-line Insurance  215.19       15.381701
# 47           Integrated Telecommunication Services   23.73       16.142857
# 48                                   Gas Utilities  142.51       20.865300
# 49                            Application Software  311.34       62.019920
#
#     Dividend Yield  Earnings/Share  52 Week Low  52 Week High    Market Cap  \
# 0           0.0199            7.15    75.652176       155.000  8.329418e+10
# 1           0.0196            3.63    66.760000        92.450  9.758165e+09
# 2           0.0202            7.64    99.710000       129.850  2.218895e+11
# 3           0.0373            2.86   153.580000       207.320  3.249770e+11
# 4           0.0170           11.92   278.690000       387.510  2.407785e+11
# 5              NaN           12.35   403.750000       638.250  1.904220e+11
# 6              NaN            1.10   112.800000       227.300  1.928863e+11
# 7           0.0615            1.44    10.810000        22.210  7.821297e+09
# 8           0.0214            6.73    75.440000       115.500  5.965260e+10
# 9              NaN             NaN   124.160000       155.350  4.327336e+10
# 10          0.0214           17.22   212.240000       337.775  7.455479e+10
# 11             NaN            2.89   110.380000       170.100  8.195133e+10
# 12             NaN            3.38    84.700000       129.170  1.500768e+10
# 13          0.0189          -16.76    71.970000       143.190  9.895693e+09
# 14          0.0520            1.80    94.350000       130.140  1.685051e+10
# 15             NaN            5.86   196.090000       335.400  1.635724e+10
# 16          0.0144            6.50   113.270000       156.100  1.153812e+10
# 17          0.0342            2.57    46.800000        64.190  1.510855e+10
# 18          0.0190           15.47   153.870000       209.880  5.092956e+10
# 19          0.0040            7.53   130.670000       205.480  2.507304e+12
# 20          0.0039            7.54   131.550000       207.080  2.504763e+12
# 21          0.0775            6.63    39.250000        58.040  8.830265e+10
# 22             NaN            4.73   151.610000       241.770  2.499205e+12
# 23          0.0523            0.53     8.780000        11.480  1.409206e+10
# 24             NaN           -0.94    18.380000        34.500  5.102043e+09
# 25          0.0285            4.25    67.030000        96.740  2.514462e+10
# 26          0.0379            4.96    75.220000       105.180  5.238309e+10
# 27          0.0086           13.94   203.000000       326.270  2.239029e+11
# 28          0.0212            5.03    67.960000        80.830  4.594683e+10
# 29          0.0349            4.14   170.460000       243.560  8.642510e+10
# 30          0.0247            5.05   113.340000       150.680  2.429159e+10
# 31          0.0103           24.93   381.990000       577.890  5.227123e+10
# 32          0.0060            5.75   149.030000       198.330  4.269020e+10
# 33          0.0335            7.88   253.300000       346.850  1.534227e+11
# 34          0.0091            1.92    51.025000        79.390  8.533307e+10
# 35          0.0165            3.27   182.570000       244.140  1.051284e+11
# 36             NaN            6.50   289.820000       363.030  3.065122e+10
# 37          0.0073           11.69   268.060000       395.330  8.019576e+10
# 38          0.0435            7.04    20.320000        36.050  8.112938e+09
# 39          0.0042            6.25   164.080000       260.100  3.572851e+12
# 40          0.0086            8.55   158.960000       255.890  1.476839e+11
# 41             NaN            8.91    51.470000        85.560  1.478611e+10
# 42             NaN           14.66    80.970000       116.470  3.558494e+10
# 43          0.0379            3.56    48.400000        66.080  2.451530e+10
# 44             NaN            2.08    60.080000       133.575  1.451621e+11
# 45          0.0087            6.49   230.080000       316.720  7.539555e+10
# 46          0.0146           13.99   160.120000       230.550  1.103654e+10
# 47          0.0489            1.47    15.940000        24.980  1.723676e+11
# 48          0.0237            6.83   110.460000       152.650  2.218026e+10
# 49             NaN            5.02   195.320000       326.620  6.709657e+10
#
#           EBITDA  Price/Sales  Price/Book  \
# 0   8.117000e+09     2.552062   17.855467
# 1   8.091000e+08     2.506078    5.091157
# 2   1.082500e+10     5.383446    5.575749
# 3   2.563000e+10     5.851963   53.882210
# 4   1.106591e+10     3.710195    8.508687
# 5   8.134000e+09     9.090657   13.383815
# 6   4.479000e+09     7.939341    3.302384
# 7   3.334000e+09     0.636706    2.377350
# 8   4.779250e+09     3.447728    2.407569
# 9            NaN          NaN         NaN
# 10  4.296600e+09     6.161247    4.380537
# 11  1.673000e+09     7.560086    9.859441
# 12  1.118398e+09     3.783850    3.138746
# 13 -9.350780e+08     1.521951    1.236089
# 14  1.905124e+09     5.461276    0.920428
# 15  8.201540e+08     4.130076    4.152799
# 16  8.884000e+08     3.098315    7.344104
# 17  1.637000e+09     3.809518    2.168293
# 18  6.193000e+09     0.815760    2.700126
# 19  1.234700e+11     7.377482    7.965486
# 20  1.234700e+11     7.370007    8.027174
# 21  1.221600e+10     4.336639         NaN
# 22  1.115830e+11     4.030144    9.640235
# 23  1.904000e+09     1.040004    3.582750
# 24  4.330000e+08     0.908483         NaN
# 25  3.264000e+09     3.562570    2.124732
# 26  7.258300e+09     2.672307    1.967633
# 27           NaN     3.779654    7.523047
# 28  8.501000e+09     1.014301    1.030815
# 29  6.966100e+09     7.738845   23.732836
# 30  2.408000e+09     5.380197    2.344311
# 31           NaN     2.996345    9.243331
# 32  2.138389e+09     6.177619    4.470064
# 33  1.224700e+10     4.715764   20.381320
# 34  3.586300e+09     5.995691    9.025759
# 35  4.361349e+09    10.837489    2.989545
# 36  8.361090e+08    12.420753    5.257001
# 37  4.295000e+09     5.372890   12.857391
# 38  5.047000e+09     0.905967    1.586257
# 39  1.346610e+11     9.136909   62.649323
# 40  8.204000e+09     5.499513    7.891743
# 41  3.033000e+09     0.749613    1.651454
# 42  5.172000e+09     2.109737    1.626131
# 43  3.988000e+09     0.276173    1.089050
# 44  2.833342e+09    21.950539    3.923926
# 45  3.382200e+09     7.067648    5.434967
# 46  1.241900e+09     0.938816    2.103704
# 47  4.277300e+10     1.412155    1.663396
# 48  1.991973e+09     5.416576    1.815761
# 49  1.396000e+09    11.558410   35.918320
#
#                                           SEC Filings
# 0   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 2   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 5   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 6   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 7   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 8   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 9   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 10  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 11  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 12  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 13  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 14  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 15  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 16  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 17  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 18  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 19  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 20  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 21  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 22  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 23  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 24  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 25  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 26  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 27  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 28  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 29  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 30  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 31  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 32  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 33  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 34  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 35  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 36  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 37  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 38  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 39  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 40  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 41  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 42  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 43  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 44  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 45  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 46  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 47  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 48  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 49  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %%
# как называются столбцы?
data.columns
# Out:
# Index(['Symbol', 'Name', 'Sector', 'Price', 'Price/Earnings', 'Dividend Yield',
#        'Earnings/Share', '52 Week Low', '52 Week High', 'Market Cap', 'EBITDA',
#        'Price/Sales', 'Price/Book', 'SEC Filings'],
#       dtype='object')

# %%
# количество строк
len(data)
# Out:
# 503

# %%
# из них строк с компаниями из отрасли 'Electric Utilities' (столбец Sector)
induk=data['Sector']=='Electric Utilities'
sum(induk)
# Out:
# 15

# %% [markdown]
# > _Примечание: так как false интерпретируется как 0, а true как 1, то sum() и дает число истинных элементов._

# %% [markdown]
# ## Группировка данных
#
# Данные можно сгруппировать по различным критериям, за это отвечает метод [`groupby()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html), к результатам которого можно применять разные функции.
#
# Общий подход показан на рисунке:
#
# данные разбиваются построчно по уникальным значениям (ключ, на рисунке столбец x), стоки с одинаковыми ключами объединяются в группы и к группам применяются заданные функции (подсчет среднего на рисунке для столбца y), затем результаты объединяются.
#
# ![img](https://drive.google.com/uc?id=1bn-KonuEYEw5hQRgCuIpiLEqQEH4YE4G)

# %%
# группируем по значениям столбцов Sector и
group=data.groupby('Sector')
group.size() # считаем количество строк, оказавшихся в каждой группе
# Out:
# Sector
# Advertising                                   2
# Aerospace & Defense                          12
# Agricultural & Farm Machinery                 1
# Agricultural Products & Services              2
# Air Freight & Logistics                       4
#                                              ..
# Tobacco                                       2
# Trading Companies & Distributors              2
# Transaction & Payment Processing Services     8
# Water Utilities                               1
# Wireless Telecommunication Services           1
# Length: 127, dtype: int64

# %%
data.count()
# Out:
# Symbol            503
# Name              503
# Sector            503
# Price             500
# Price/Earnings    475
# Dividend Yield    404
# Earnings/Share    499
# 52 Week Low       500
# 52 Week High      500
# Market Cap        500
# EBITDA            470
# Price/Sales       499
# Price/Book        468
# SEC Filings       503
# dtype: int64

# %%
group.count() # число раз, когда значение группы встречалось
# может быть меньше, чем число строк, если значение было пропущено в файле
# Out:
#                                            Symbol  Name  Price  \
# Sector
# Advertising                                     2     2      2
# Aerospace & Defense                            12    12     12
# Agricultural & Farm Machinery                   1     1      1
# Agricultural Products & Services                2     2      2
# Air Freight & Logistics                         4     4      4
# ...                                           ...   ...    ...
# Tobacco                                         2     2      2
# Trading Companies & Distributors                2     2      2
# Transaction & Payment Processing Services       8     8      8
# Water Utilities                                 1     1      1
# Wireless Telecommunication Services             1     1      1
#
#                                            Price/Earnings  Dividend Yield  \
# Sector
# Advertising                                             2               2
# Aerospace & Defense                                    11               9
# Agricultural & Farm Machinery                           1               1
# Agricultural Products & Services                        2               2
# Air Freight & Logistics                                 4               4
# ...                                                   ...             ...
# Tobacco                                                 2               2
# Trading Companies & Distributors                        2               2
# Transaction & Payment Processing Services               8               5
# Water Utilities                                         1               1
# Wireless Telecommunication Services                     1               1
#
#                                            Earnings/Share  52 Week Low  \
# Sector
# Advertising                                             2            2
# Aerospace & Defense                                    12           12
# Agricultural & Farm Machinery                           1            1
# Agricultural Products & Services                        2            2
# Air Freight & Logistics                                 4            4
# ...                                                   ...          ...
# Tobacco                                                 2            2
# Trading Companies & Distributors                        2            2
# Transaction & Payment Processing Services               8            8
# Water Utilities                                         1            1
# Wireless Telecommunication Services                     1            1
#
#                                            52 Week High  Market Cap  EBITDA  \
# Sector
# Advertising                                           2           2       2
# Aerospace & Defense                                  12          12      12
# Agricultural & Farm Machinery                         1           1       1
# Agricultural Products & Services                      2           2       2
# Air Freight & Logistics                               4           4       4
# ...                                                 ...         ...     ...
# Tobacco                                               2           2       2
# Trading Companies & Distributors                      2           2       2
# Transaction & Payment Processing Services             8           8       8
# Water Utilities                                       1           1       1
# Wireless Telecommunication Services                   1           1       1
#
#                                            Price/Sales  Price/Book  \
# Sector
# Advertising                                          2           2
# Aerospace & Defense                                 12          10
# Agricultural & Farm Machinery                        1           1
# Agricultural Products & Services                     2           2
# Air Freight & Logistics                              4           4
# ...                                                ...         ...
# Tobacco                                              2           0
# Trading Companies & Distributors                     2           2
# Transaction & Payment Processing Services            8           8
# Water Utilities                                      1           1
# Wireless Telecommunication Services                  1           1
#
#                                            SEC Filings
# Sector
# Advertising                                          2
# Aerospace & Defense                                 12
# Agricultural & Farm Machinery                        1
# Agricultural Products & Services                     2
# Air Freight & Logistics                              4
# ...                                                ...
# Tobacco                                              2
# Trading Companies & Distributors                     2
# Transaction & Payment Processing Services            8
# Water Utilities                                      1
# Wireless Telecommunication Services                  1
#
# [127 rows x 13 columns]

# %%
#group.Price.median() # медиана для групп по числовому столбцу Price
# тут-то нам и пригодилось обращение к столбцу как к атрибуту

group['Price'].median() # альтернативное написание
# Out:
# Sector
# Advertising                                   57.730
# Aerospace & Defense                          207.790
# Agricultural & Farm Machinery                476.560
# Agricultural Products & Services              63.680
# Air Freight & Logistics                      113.905
#                                               ...
# Tobacco                                       91.215
# Trading Companies & Distributors             415.650
# Transaction & Payment Processing Services    195.065
# Water Utilities                              124.640
# Wireless Telecommunication Services          232.970
# Name: Price, Length: 127, dtype: float64

# %%
data['Price'].median()
# Out:
# 122.19999999999999

# %%
# каждую группу можно посмотреть, вот состав группы Materials
group.get_group('Advertising')
# Out:
#     Symbol                                  Name       Sector  Price  \
# 255    IPG  Interpublic Group of Companies (The)  Advertising  28.67
# 356    OMC                         Omnicom Group  Advertising  86.79
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 255       13.523585          0.0460            2.12        26.30
# 356       11.856557          0.0324            7.32        81.42
#
#      52 Week High    Market Cap        EBITDA  Price/Sales  Price/Book  \
# 255         35.17  1.068001e+10  1.732100e+09     1.143604    2.866427
# 356        107.00  1.705259e+10  2.420600e+09     1.105315    4.285291
#
#                                            SEC Filings
# 255  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 356  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %% [markdown]
# Уникальные (т.е. без повторов) названия (столбец Name) компаний в каждой группе.

# %%
group.Name.unique()
# Out:
# Sector
# Advertising                                  [Interpublic Group of Companies (The), Omnicom...
# Aerospace & Defense                          [Axon Enterprise, Boeing, GE Aerospace, Genera...
# Agricultural & Farm Machinery                                                [Deere & Company]
# Agricultural Products & Services                        [Archer Daniels Midland, Bunge Global]
# Air Freight & Logistics                      [C.H. Robinson, Expeditors International, FedE...
#                                                                    ...
# Tobacco                                                  [Altria, Philip Morris International]
# Trading Companies & Distributors                                    [Fastenal, United Rentals]
# Transaction & Payment Processing Services    [Corpay, Fidelity National Information Service...
# Water Utilities                                                         [American Water Works]
# Wireless Telecommunication Services                                              [T-Mobile US]
# Name: Name, Length: 127, dtype: object

# %% [markdown]
# Каждая группа здесь это кортеж названий и содержания (последовательность) группы.
#
# Посмотрим, есть ли в группе хоть одна фирма с аббревиатурой (столбец Symbol) начинающейся на букву "А".

# %%
letter="A"
for i in group.Symbol:
    print('{}: {}'.format(i[0],(i[1].str.get(0)==letter).any()))
# Out:
# Advertising: False
# Aerospace & Defense: True
# Agricultural & Farm Machinery: False
# Agricultural Products & Services: True
# Air Freight & Logistics: False
# Apparel Retail: False
# Apparel, Accessories & Luxury Goods: False
# Application Software: True
# Asset Management & Custody Banks: True
# Automobile Manufacturers: False
# Automotive Parts & Equipment: True
# Automotive Retail: True
# Biotechnology: True
# Brewers: False
# Broadcasting: False
# Broadline Retail: True
# Building Products: True
# Cable & Satellite: False
# Cargo Ground Transportation: False
# Casinos & Gaming: False
# Commodity Chemicals: False
# Communications Equipment: True
# Computer & Electronics Retail: False
# Construction & Engineering: False
# Construction Machinery & Heavy Transportation Equipment: False
# Construction Materials: False
# Consumer Electronics: False
# Consumer Finance: True
# Consumer Staples Merchandise Retail: False
# Copper: False
# Data Center REITs: False
# Data Processing & Outsourced Services: False
# Distillers & Vintners: False
# Distributors: False
# Diversified Banks: False
# Diversified Support Services: True
# Drug Retail: False
# Electric Utilities: True
# Electrical Components & Equipment: True
# Electronic Components: True
# Electronic Equipment & Instruments: False
# Electronic Manufacturing Services: False
# Environmental & Facilities Services: False
# Fertilizers & Agricultural Chemicals: False
# Financial Exchanges & Data: False
# Food Distributors: False
# Food Retail: False
# Footwear: False
# Gas Utilities: True
# Gold: False
# Health Care Distributors: False
# Health Care Equipment: True
# Health Care Facilities: False
# Health Care REITs: False
# Health Care Services: False
# Health Care Supplies: True
# Health Care Technology: False
# Heavy Electrical Equipment: False
# Home Furnishings: False
# Home Improvement Retail: False
# Homebuilding: False
# Hotel & Resort REITs: False
# Hotels, Resorts & Cruise Lines: True
# Household Products: False
# Human Resource & Employment Services: True
# IT Consulting & Other Services: True
# Independent Power Producers & Energy Traders: True
# Industrial Conglomerates: False
# Industrial Gases: True
# Industrial Machinery & Supplies & Components: False
# Industrial REITs: False
# Insurance Brokers: True
# Integrated Oil & Gas: False
# Integrated Telecommunication Services: False
# Interactive Home Entertainment: False
# Interactive Media & Services: False
# Internet Services & Infrastructure: True
# Investment Banking & Brokerage: False
# Leisure Products: False
# Life & Health Insurance: True
# Life Sciences Tools & Services: True
# Managed Health Care: False
# Metal, Glass & Plastic Containers: False
# Movies & Entertainment: False
# Multi-Family Residential REITs: True
# Multi-Sector Holdings: False
# Multi-Utilities: True
# Multi-line Insurance: True
# Office REITs: True
# Oil & Gas Equipment & Services: False
# Oil & Gas Exploration & Production: True
# Oil & Gas Refining & Marketing: False
# Oil & Gas Storage & Transportation: False
# Other Specialized REITs: False
# Other Specialty Retail: False
# Packaged Foods & Meats: False
# Paper & Plastic Packaging Products & Materials: True
# Passenger Airlines: False
# Passenger Ground Transportation: False
# Personal Care Products: False
# Pharmaceuticals: False
# Property & Casualty Insurance: True
# Publishing: False
# Rail Transportation: False
# Real Estate Services: False
# Regional Banks: False
# Reinsurance: False
# Research & Consulting Services: False
# Restaurants: False
# Retail REITs: False
# Self-Storage REITs: False
# Semiconductor Materials & Equipment: True
# Semiconductors: True
# Single-Family Residential REITs: False
# Soft Drinks & Non-alcoholic Beverages: False
# Specialty Chemicals: True
# Steel: False
# Systems Software: False
# Technology Distributors: False
# Technology Hardware, Storage & Peripherals: True
# Telecom Tower REITs: True
# Timber REITs: False
# Tobacco: False
# Trading Companies & Distributors: False
# Transaction & Payment Processing Services: False
# Water Utilities: True
# Wireless Telecommunication Services: False

# %% [markdown]
# Что здесь происходит:
# - группы можно итерировать, в цикле переменная i будет являться последовательно кортежем из названия и содержание каждой из групп в которой оставлен только столбец Symbol.
# - i[0] - название группы, i[1] - содержимое текущей группы, в нашем случае это объект типа Series.
# - у этого объекта Series есть атрибут str, который позволяет работать с элементами как со строкой.
# - метод get() для строки возвращает символ строки на определенном месте, 0 - это первый символ.
# - сравниваем этот первый символ с буквой "A", получаем или истину или ложь.
# - так как в группе может быть не одна строка, то в результате получится логический вектор (тип Series) из значений истина\ложь.
# - метод any() для логических векторов возвращает истину если хотя бы один элемент вектора истинный, что нам и требуется.
# - наконец печатаем результат.

# %% [markdown]
# Агрегировать группы можно разными функциями, даже своими собственными, в этом помогает метод [`agg()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.core.groupby.GroupBy.agg.html?highlight=agg#pandas.core.groupby.GroupBy.agg), который позволяет применять одну или несколько функций к группам. Давайте сделаем свою функцию и применим ее к группам.

# %%
# своя функция, которая вычитает минимальное значение из максимального
def max_min(arr):
    return arr.max() - arr.min()

# считаем по группам для столбца Price свою функцию и среднее.
result=group.Price.agg([max_min, 'mean'])
result
# Out:
#                                            max_min        mean
# Sector
# Advertising                                  58.12   57.730000
# Aerospace & Defense                        1276.83  361.176667
# Agricultural & Farm Machinery                 0.00  476.560000
# Agricultural Products & Services             24.90   63.680000
# Air Freight & Logistics                     165.38  148.042500
# ...                                            ...         ...
# Tobacco                                      77.97   91.215000
# Trading Companies & Distributors            684.82  415.650000
# Transaction & Payment Processing Services   473.96  243.843750
# Water Utilities                               0.00  124.640000
# Wireless Telecommunication Services           0.00  232.970000
#
# [127 rows x 2 columns]

# %% [markdown]
# ## Разбивка на интервалы
# Значения в столбце можно разбить на интервалы, назвать их и записать эти интервалы вместо значений. В этом поможет команда [`cut`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html?highlight=cut#pandas.cut) которой указываем что разбивать, сколько интервалов сделать, их названия и другие аргументы.

# %%
data['Price']
# Out:
# 0      152.20
# 1       67.30
# 2      127.93
# 3      183.90
# 4      384.95
#         ...
# 498    124.04
# 499    130.50
# 500    391.94
# 501    109.48
# 502    170.90
# Name: Price, Length: 503, dtype: float64

# %%
# разбиваем столбец Price на 5 интервалов, называем их.
cuted=pd.cut(data['Price'], 5,labels=['Low','Medium','High','Very High','Exclusive'], include_lowest=True)
cuted
# Out:
# 0      Low
# 1      Low
# 2      Low
# 3      Low
# 4      Low
#       ...
# 498    Low
# 499    Low
# 500    Low
# 501    Low
# 502    Low
# Name: Price, Length: 503, dtype: category
# Categories (5, object): ['Low' < 'Medium' < 'High' < 'Very High' < 'Exclusive']

# %% [markdown]
# Заменим столбец Price на cuted

# %%
data['Price']=cuted
data
# Out:
#     Symbol                 Name                                        Sector  \
# 0      MMM                   3M                      Industrial Conglomerates
# 1      AOS          A. O. Smith                             Building Products
# 2      ABT  Abbott Laboratories                         Health Care Equipment
# 3     ABBV               AbbVie                                 Biotechnology
# 4      ACN            Accenture                IT Consulting & Other Services
# ..     ...                  ...                                           ...
# 498    XYL           Xylem Inc.  Industrial Machinery & Supplies & Components
# 499    YUM          Yum! Brands                                   Restaurants
# 500   ZBRA   Zebra Technologies            Electronic Equipment & Instruments
# 501    ZBH        Zimmer Biomet                         Health Care Equipment
# 502    ZTS               Zoetis                               Pharmaceuticals
#
#     Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0     Low       21.286713          0.0199            7.15    75.652176
# 1     Low       18.539946          0.0196            3.63    66.760000
# 2     Low       16.744764          0.0202            7.64    99.710000
# 3     Low       64.300700          0.0373            2.86   153.580000
# 4     Low       32.294464          0.0170           11.92   278.690000
# ..    ...             ...             ...             ...          ...
# 498   Low       35.643677          0.0118            3.48   112.020000
# 499   Low       24.392525          0.0205            5.35   122.130000
# 500   Low       53.397820             NaN            7.34   237.060000
# 501   Low       20.893131          0.0087            5.24   100.670000
# 502   Low       32.124058          0.0116            5.32   144.800000
#
#      52 Week High    Market Cap        EBITDA  Price/Sales  Price/Book  \
# 0          155.00  8.329418e+10  8.117000e+09     2.552062   17.855467
# 1           92.45  9.758165e+09  8.091000e+08     2.506078    5.091157
# 2          129.85  2.218895e+11  1.082500e+10     5.383446    5.575749
# 3          207.32  3.249770e+11  2.563000e+10     5.851963   53.882210
# 4          387.51  2.407785e+11  1.106591e+10     3.710195    8.508687
# ..            ...           ...           ...          ...         ...
# 498        146.08  3.013490e+10  1.689000e+09     3.577267    2.845411
# 499        143.20  3.641890e+10  2.608000e+09     5.042073         NaN
# 500        427.76  2.021626e+10  8.030000e+08     4.341981    5.905112
# 501        133.90  2.179462e+10  2.557400e+09     2.869412    1.765892
# 502        200.53  7.710410e+10  3.764000e+09     8.424835   14.744198
#
#                                            SEC Filings
# 0    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 2    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4    http://www.sec.gov/cgi-bin/browse-edgar?action...
# ..                                                 ...
# 498  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 499  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 500  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 501  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 502  http://www.sec.gov/cgi-bin/browse-edgar?action...
#
# [503 rows x 14 columns]

# %%
data['Price111']='Нечто'

# %%
data.head()
# Out:
#   Symbol                 Name                          Sector Price  \
# 0    MMM                   3M        Industrial Conglomerates   Low
# 1    AOS          A. O. Smith               Building Products   Low
# 2    ABT  Abbott Laboratories           Health Care Equipment   Low
# 3   ABBV               AbbVie                   Biotechnology   Low
# 4    ACN            Accenture  IT Consulting & Other Services   Low
#
#    Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  52 Week High  \
# 0       21.286713          0.0199            7.15    75.652176        155.00
# 1       18.539946          0.0196            3.63    66.760000         92.45
# 2       16.744764          0.0202            7.64    99.710000        129.85
# 3       64.300700          0.0373            2.86   153.580000        207.32
# 4       32.294464          0.0170           11.92   278.690000        387.51
#
#      Market Cap        EBITDA  Price/Sales  Price/Book  \
# 0  8.329418e+10  8.117000e+09     2.552062   17.855467
# 1  9.758165e+09  8.091000e+08     2.506078    5.091157
# 2  2.218895e+11  1.082500e+10     5.383446    5.575749
# 3  3.249770e+11  2.563000e+10     5.851963   53.882210
# 4  2.407785e+11  1.106591e+10     3.710195    8.508687
#
#                                          SEC Filings Price111
# 0  http://www.sec.gov/cgi-bin/browse-edgar?action...    Нечто
# 1  http://www.sec.gov/cgi-bin/browse-edgar?action...    Нечто
# 2  http://www.sec.gov/cgi-bin/browse-edgar?action...    Нечто
# 3  http://www.sec.gov/cgi-bin/browse-edgar?action...    Нечто
# 4  http://www.sec.gov/cgi-bin/browse-edgar?action...    Нечто

# %% [markdown]
# В качестве упражнения выведите на экран название (Name) фирмы, у которой цена (Price) входит в интервал Exclusive

# %%
data[data['Price']=='Exclusive']['Name']
# Out:
# 351    NVR, Inc.
# Name: Name, dtype: object

# %% [markdown]
# # Задания
# Тщательно изучите документацию на библиотеку pandas и попробуйте самостоятельно выполнить группировку по другим столбцам.

# %% [markdown]
# # Ссылки
#
# https://pythonru.com/biblioteki/struktury-dannyh-v-pandas
